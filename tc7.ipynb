# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevita-R/da_notes/blob/main/tc7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file='https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/titanic.csv'
df=pd.read_csv(file)
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df['cabin'][df['cabin'].notnull()]
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1189         G6
# 1217      F G73
# 1230         G6
# 1231         G6
# 1249        F38
# Name: cabin, Length: 295, dtype: object

# %%
file='https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/amazon_fires.csv'
df=pd.read_csv(file,encoding='ISO-8859-1')
df
# Out:
#        ano       mes     estado   numero  encontro
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.shape
# Out:
# (6454, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano       6454 non-null   int64
#  1   mes       6454 non-null   object
#  2   estado    6454 non-null   object
#  3   numero    6322 non-null   object
#  4   encontro  6454 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 252.2+ KB

# %%
len(df['estado'].unique())
# Out:
# 23

# %%
len(df['mes'].unique())
# Out:
# 12

# %%
df['mes'].value_counts()
# Out:
# mes
# Janeiro      541
# Fevereiro    540
# Março        540
# Abril        540
# Maio         540
# Junho        540
# Julho        540
# Agosto       540
# Setembro     540
# Outubro      540
# Novembro     540
# Dezembro     513
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     ano      mes estado   numero  encontro
# 0  1998  Janeiro   Acre  0 Fires  1/1/1998
# 1  1999  Janeiro   Acre  0 Fires  1/1/1999
# 2  2000  Janeiro   Acre  0 Fires  1/1/2000
# 3  2001  Janeiro   Acre  0 Fires  1/1/2001
# 4  2002  Janeiro   Acre  0 Fires  1/1/2002

# %%
new_cols={'ano':'year','mes':'month','estado':'state','numero':'no_of_fires',
          'encontro':'date'}
df.rename(columns=new_cols,inplace=True)

# %%
df.head()
# Out:
#    year    month state no_of_fires      date
# 0  1998  Janeiro  Acre     0 Fires  1/1/1998
# 1  1999  Janeiro  Acre     0 Fires  1/1/1999
# 2  2000  Janeiro  Acre     0 Fires  1/1/2000
# 3  2001  Janeiro  Acre     0 Fires  1/1/2001
# 4  2002  Janeiro  Acre     0 Fires  1/1/2002

# %%
d={'name':['A','B','C','A','D','B'],
   'age':[12,34,56,12,56,34],
   'name':['B','B','C','A','A','B']}
df1=pd.DataFrame(d)
df1
# Out:
#   name  age
# 0    B   12
# 1    B   34
# 2    C   56
# 3    A   12
# 4    A   56
# 5    B   34

# %%
df1.drop_duplicates()
# Out:
#   name  age
# 0    B   12
# 1    B   34
# 2    C   56
# 3    A   12
# 4    A   56

# %%
df1
# Out:
#   name  age
# 0    B   12
# 1    B   34
# 2    C   56
# 3    A   12
# 4    A   56
# 5    B   34

# %%
df.head()
# Out:
#    year    month state no_of_fires      date
# 0  1998  Janeiro  Acre     0 Fires  1/1/1998
# 1  1999  Janeiro  Acre     0 Fires  1/1/1999
# 2  2000  Janeiro  Acre     0 Fires  1/1/2000
# 3  2001  Janeiro  Acre     0 Fires  1/1/2001
# 4  2002  Janeiro  Acre     0 Fires  1/1/2002

# %%
df['month'].unique()
# Out:
# array(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho',
#        'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'],
#       dtype=object)

# %%
new_data={'Janeiro':'January', 'Fevereiro':'February', 'Março':'March',
          'Abril':'April', 'Maio':'May', 'Junho':'June', 'Julho':'July',
       'Agosto':'August', 'Setembro':'September', 'Outubro':'October',
          'Novembro':'November','Dezembro':'December'}
df['month']=df['month'].map(new_data)

# %%
df
# Out:
#       year     month      state no_of_fires      date
# 0     1998   January       Acre     0 Fires  1/1/1998
# 1     1999   January       Acre     0 Fires  1/1/1999
# 2     2000   January       Acre     0 Fires  1/1/2000
# 3     2001   January       Acre     0 Fires  1/1/2001
# 4     2002   January       Acre     0 Fires  1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  December  Tocantins         128  1/1/2012
# 6450  2013  December  Tocantins          85  1/1/2013
# 6451  2014  December  Tocantins         223  1/1/2014
# 6452  2015  December  Tocantins         373  1/1/2015
# 6453  2016  December  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df1
# Out:
#   name  age
# 0    B   12
# 1    B   34
# 2    C   56
# 3    A   12
# 4    A   56
# 5    B   34

# %%
df1['name'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
d={'B':'Bharath','A':'Akash','C':'Charan'}
df1['name']=df1['name'].map(d)

# %%
df1
# Out:
#       name  age
# 0  Bharath   12
# 1  Bharath   34
# 2   Charan   56
# 3    Akash   12
# 4    Akash   56
# 5  Bharath   34

# %%
df.head()
# Out:
#    year    month state no_of_fires      date
# 0  1998  January  Acre     0 Fires  1/1/1998
# 1  1999  January  Acre     0 Fires  1/1/1999
# 2  2000  January  Acre     0 Fires  1/1/2000
# 3  2001  January  Acre     0 Fires  1/1/2001
# 4  2002  January  Acre     0 Fires  1/1/2002

# %%
df['no_of_fires']=df['no_of_fires'].str.strip(' Fires')
df
# Out:
#       year     month      state no_of_fires      date
# 0     1998   January       Acre           0  1/1/1998
# 1     1999   January       Acre           0  1/1/1999
# 2     2000   January       Acre           0  1/1/2000
# 3     2001   January       Acre           0  1/1/2001
# 4     2002   January       Acre           0  1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  December  Tocantins         128  1/1/2012
# 6450  2013  December  Tocantins          85  1/1/2013
# 6451  2014  December  Tocantins         223  1/1/2014
# 6452  2015  December  Tocantins         373  1/1/2015
# 6453  2016  December  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df['month']=df['month'].str.capitalize()
df
# Out:
#       year     month      state no_of_fires      date
# 0     1998   January       Acre           0  1/1/1998
# 1     1999   January       Acre           0  1/1/1999
# 2     2000   January       Acre           0  1/1/2000
# 3     2001   January       Acre           0  1/1/2001
# 4     2002   January       Acre           0  1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  December  Tocantins         128  1/1/2012
# 6450  2013  December  Tocantins          85  1/1/2013
# 6451  2014  December  Tocantins         223  1/1/2014
# 6452  2015  December  Tocantins         373  1/1/2015
# 6453  2016  December  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6454 non-null   int64
#  1   month        6454 non-null   object
#  2   state        6454 non-null   object
#  3   no_of_fires  6322 non-null   object
#  4   date         6454 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 252.2+ KB

# %%
#df.dropna(inplace=True)

# %%
df[df['no_of_fires'].isnull()]
# Out:
#       year      month      state no_of_fires      date
# 68    2006      April       Acre         NaN  1/1/2006
# 110   2008       June       Acre         NaN  1/1/2008
# 127   2005       July       Acre         NaN  1/1/2005
# 206   2004   November       Acre         NaN  1/1/2004
# 217   2015   November       Acre         NaN  1/1/2015
# ...    ...        ...        ...         ...       ...
# 6305  2008        May  Tocantins         NaN  1/1/2008
# 6354  2017       July  Tocantins         NaN  1/1/2017
# 6383  2006  September  Tocantins         NaN  1/1/2006
# 6415  1998   November  Tocantins         NaN  1/1/1998
# 6428  2011   November  Tocantins         NaN  1/1/2011
#
# [132 rows x 5 columns]

# %%
df['no_of_fires'][65:70]
# Out:
# 65      1
# 66      2
# 67      1
# 68    NaN
# 69      0
# Name: no_of_fires, dtype: object

# %%
#df['no_of_fires']=df['no_of_fires'].fillna(3)

# %%
#df['no_of_fires'][65:70]

# %%
#df.info()

# %%
df['no_of_fires'][65:70]
# Out:
# 65      1
# 66      2
# 67      1
# 68    NaN
# 69      0
# Name: no_of_fires, dtype: object

# %%
df['no_of_fires']=df['no_of_fires'].fillna(method='backfill')
# Out:
# <ipython-input-142-8770828cfe7b>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['no_of_fires']=df['no_of_fires'].fillna(method='backfill')

# %%
df['no_of_fires'][65:70]
# Out:
# 65    1
# 66    2
# 67    1
# 68    0
# 69    0
# Name: no_of_fires, dtype: object

# %%
d={'a':[1,2,3,4,None,8,None],'b':[None,67,5,7,None,None,7]}
df1=pd.DataFrame(d)
df1
# Out:
#      a     b
# 0  1.0   NaN
# 1  2.0  67.0
# 2  3.0   5.0
# 3  4.0   7.0
# 4  NaN   NaN
# 5  8.0   NaN
# 6  NaN   7.0

# %%
df1['b']=df1['b'].fillna(method='backfill')
df1
# Out:
# <ipython-input-145-a6b963b584d2>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['b']=df1['b'].fillna(method='backfill')
#      a     b
# 0  1.0  67.0
# 1  2.0  67.0
# 2  3.0   5.0
# 3  4.0   7.0
# 4  NaN   7.0
# 5  8.0   7.0
# 6  NaN   7.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6454 non-null   int64
#  1   month        6454 non-null   object
#  2   state        6454 non-null   object
#  3   no_of_fires  6454 non-null   object
#  4   date         6454 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 252.2+ KB

# %%
df.head() #[date,year,month,state,no_of_fires]
# Out:
#    year    month state no_of_fires      date
# 0  1998  January  Acre           0  1/1/1998
# 1  1999  January  Acre           0  1/1/1999
# 2  2000  January  Acre           0  1/1/2000
# 3  2001  January  Acre           0  1/1/2001
# 4  2002  January  Acre           0  1/1/2002

# %%
new=[4,0,1,2,3]
df=df[df.columns[new]]
df.head()
# Out:
#        date  year    month state no_of_fires
# 0  1/1/1998  1998  January  Acre           0
# 1  1/1/1999  1999  January  Acre           0
# 2  1/1/2000  2000  January  Acre           0
# 3  1/1/2001  2001  January  Acre           0
# 4  1/1/2002  2002  January  Acre           0

# %%
df
# Out:
#           date  year     month      state no_of_fires
# 0     1/1/1998  1998   January       Acre           0
# 1     1/1/1999  1999   January       Acre           0
# 2     1/1/2000  2000   January       Acre           0
# 3     1/1/2001  2001   January       Acre           0
# 4     1/1/2002  2002   January       Acre           0
# ...        ...   ...       ...        ...         ...
# 6449  1/1/2012  2012  December  Tocantins         128
# 6450  1/1/2013  2013  December  Tocantins          85
# 6451  1/1/2014  2014  December  Tocantins         223
# 6452  1/1/2015  2015  December  Tocantins         373
# 6453  1/1/2016  2016  December  Tocantins         119
#
# [6454 rows x 5 columns]

# %%
df['month']=df['month'].str.replace('January','Jan')
df
# Out:
#           date  year     month      state no_of_fires
# 0     1/1/1998  1998       Jan       Acre           0
# 1     1/1/1999  1999       Jan       Acre           0
# 2     1/1/2000  2000       Jan       Acre           0
# 3     1/1/2001  2001       Jan       Acre           0
# 4     1/1/2002  2002       Jan       Acre           0
# ...        ...   ...       ...        ...         ...
# 6449  1/1/2012  2012  December  Tocantins         128
# 6450  1/1/2013  2013  December  Tocantins          85
# 6451  1/1/2014  2014  December  Tocantins         223
# 6452  1/1/2015  2015  December  Tocantins         373
# 6453  1/1/2016  2016  December  Tocantins         119
#
# [6454 rows x 5 columns]

# %%
df.drop('year',axis=1,inplace=True)

# %%
df.head()
# Out:
#        date month state no_of_fires
# 0  1/1/1998   Jan  Acre           0
# 1  1/1/1999   Jan  Acre           0
# 2  1/1/2000   Jan  Acre           0
# 3  1/1/2001   Jan  Acre           0
# 4  1/1/2002   Jan  Acre           0

# %%
df.drop(['month','no_of_fires'],axis=1)
# Out:
#           date      state
# 0     1/1/1998       Acre
# 1     1/1/1999       Acre
# 2     1/1/2000       Acre
# 3     1/1/2001       Acre
# 4     1/1/2002       Acre
# ...        ...        ...
# 6449  1/1/2012  Tocantins
# 6450  1/1/2013  Tocantins
# 6451  1/1/2014  Tocantins
# 6452  1/1/2015  Tocantins
# 6453  1/1/2016  Tocantins
#
# [6454 rows x 2 columns]

# %%
df.head()
# Out:
#        date month state no_of_fires
# 0  1/1/1998   Jan  Acre           0
# 1  1/1/1999   Jan  Acre           0
# 2  1/1/2000   Jan  Acre           0
# 3  1/1/2001   Jan  Acre           0
# 4  1/1/2002   Jan  Acre           0

# %%
df.drop(df.index[[5,6450,6452]])
# Out:
#           date     month      state no_of_fires
# 0     1/1/1998       Jan       Acre           0
# 1     1/1/1999       Jan       Acre           0
# 2     1/1/2000       Jan       Acre           0
# 3     1/1/2001       Jan       Acre           0
# 4     1/1/2002       Jan       Acre           0
# ...        ...       ...        ...         ...
# 6447  1/1/2010  December  Tocantins          72
# 6448  1/1/2011  December  Tocantins         105
# 6449  1/1/2012  December  Tocantins         128
# 6451  1/1/2014  December  Tocantins         223
# 6453  1/1/2016  December  Tocantins         119
#
# [6451 rows x 4 columns]

# %%
df=df.reset_index()

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.drop(3)
# Out:
#           date     month      state no_of_fires
# 0     1/1/1998       Jan       Acre           0
# 1     1/1/1999       Jan       Acre           0
# 2     1/1/2000       Jan       Acre           0
# 4     1/1/2002       Jan       Acre           0
# 5     1/1/2003       Jan       Acre          10
# ...        ...       ...        ...         ...
# 6449  1/1/2012  December  Tocantins         128
# 6450  1/1/2013  December  Tocantins          85
# 6451  1/1/2014  December  Tocantins         223
# 6452  1/1/2015  December  Tocantins         373
# 6453  1/1/2016  December  Tocantins         119
#
# [6453 rows x 4 columns]

# %%
df.set_index('month')
# Out:
#               date      state no_of_fires
# month
# Jan       1/1/1998       Acre           0
# Jan       1/1/1999       Acre           0
# Jan       1/1/2000       Acre           0
# Jan       1/1/2001       Acre           0
# Jan       1/1/2002       Acre           0
# ...            ...        ...         ...
# December  1/1/2012  Tocantins         128
# December  1/1/2013  Tocantins          85
# December  1/1/2014  Tocantins         223
# December  1/1/2015  Tocantins         373
# December  1/1/2016  Tocantins         119
#
# [6454 rows x 3 columns]
