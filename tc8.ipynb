# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevita-R/da_notes/blob/main/tc8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file='https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/hr_data.csv'
df=pd.read_csv(file)
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
v=df.groupby('department')

# %%
v.groups
# Out:
# {'IT': [61, 62, 63, 64, 65, 70, 138, 139, 140, 141, 142, 147, 214, 215, 216, 217, 218, 223, 291, 292, 293, 294, 295, 300, 367, 368, 369, 370, 371, 376, 443, 444, 445, 446, 447, 452, 519, 520, 521, 522, 523, 528, 595, 596, 597, 598, 599, 604, 671, 672, 673, 674, 675, 680, 747, 748, 749, 750, 751, 756, 823, 824, 825, 826, 827, 832, 899, 900, 901, 902, 903, 908, 975, 976, 977, 978, 979, 984, 1051, 1052, 1053, 1054, 1055, 1060, 1127, 1128, 1129, 1130, 1131, 1136, 1204, 1205, 1206, 1207, 1208, 1213, 1214, 1215, 1216, 1281, ...], 'RandD': [301, 302, 303, 304, 305, 453, 454, 455, 456, 457, 605, 606, 607, 608, 609, 833, 834, 835, 836, 837, 985, 986, 987, 988, 989, 1061, 1062, 1063, 1064, 1065, 1217, 1218, 1219, 1291, 1292, 1293, 1294, 1295, 1296, 1368, 1369, 1370, 1371, 1372, 1373, 1445, 1446, 1447, 1448, 1449, 1450, 1522, 1523, 1524, 1525, 1526, 1598, 1599, 1600, 1601, 1602, 1675, 1676, 1677, 1678, 1679, 1751, 1752, 1753, 1754, 1755, 1827, 1828, 1829, 1830, 1831, 1903, 1904, 1905, 1906, 190
# ...

# %%
v.get_group('hr')
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 31            1223               2                   134                   3
# 32            1228               2                   145                   3
# 33            1230               2                   140                   3
# 34            1236               4                   246                   6
# 108           1679               3                   177                   4
# ...            ...             ...                   ...                 ...
# 14902        87131               2                   159                   3
# 14975        87560               7                   310                   4
# 14976        87562               2                   136                   3
# 14977        87579               4                   251                   6
# 14978        17938               2                   144                   3
#
# ...

# %%
ac=v.get_group('accounting')
ac
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 28            1203               2                   128                   3
# 29            1204               2                   132                   3
# 30            1214               6                   294                   4
# 79            1489               2                   142                   3
# 105           1669               7                   224                   5
# ...            ...             ...                   ...                 ...
# 14898        87115               7                   269                   4
# 14946        87365               5                   303                   5
# 14972        87539               6                   310                   4
# 14973         7745               2                   143                   3
# 14974        87545               2                   153                   3
#
# ...

# %%
ac['number_project'].mean()
# Out:
# 3.8252933507170797

# %%
sum(ac['number_project'])
# Out:
# 2934

# %%
it_dep=v.get_group('IT')
it_dep
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 61            1399               7                   308                   4
# 62            1404               6                   244                   5
# 63            1413               2                   132                   3
# 64           42423               6                   286                   4
# 65            1424               6                   161                   4
# ...            ...             ...                   ...                 ...
# 14930        87284               6                   268                   4
# 14931        87288               5                   240                   5
# 14932        87294               2                   127                   3
# 14933        87308               7                   264                   4
# 14938        45511               4                   271                   5
#
# ...

# %%
it_dep[it_dep['promotion_last_5years']==1].count()
# Out:
# employee_id              3
# number_project           3
# average_montly_hours     3
# time_spend_company       3
# Work_accident            3
# left                     3
# promotion_last_5years    3
# department               3
# salary                   3
# dtype: int64

# %%
it_dep['promotion_last_5years'].count()
# Out:
# 1227

# %%
mng=v.get_group('management')
mng

# %%
mng[mng['salary']=='medium']['time_spend_company'].sum()
# Out:
# 935

# %%
d={'ename':['A','B','C','D','E','A','F'],
   'eid':[12,34,13,5,32,11,3],
   'dept_no':[1,2,3,1,1,2,7]}
df1=pd.DataFrame(d)
df1
# Out:
#   ename  eid  dept_no
# 0     A   12        1
# 1     B   34        2
# 2     C   13        3
# 3     D    5        1
# 4     E   32        1
# 5     A   11        2
# 6     F    3        7

# %%
df2=pd.DataFrame({'dept_no':[1,2,3,4],
                  'dept_name':['dev','test','database','r&d']})
df2
# Out:
#    dept_no dept_name
# 0        1       dev
# 1        2      test
# 2        3  database
# 3        4       r&d

# %%
d=pd.concat([df1,df2],axis=1)

# %%
d['dept_no'][2:5]
# Out:
#    dept_no  dept_no
# 2        3      3.0
# 3        1      NaN
# 4        1      NaN

# %%
pd.concat([df1,df2])
# Out:
#   ename   eid  dept_no dept_name
# 0     A  12.0        1       NaN
# 1     B  34.0        2       NaN
# 2     C  13.0        3       NaN
# 3     D   5.0        1       NaN
# 4     E  32.0        1       NaN
# 5     A  11.0        2       NaN
# 0   NaN   NaN        1       dev
# 1   NaN   NaN        2      test
# 2   NaN   NaN        3  database

# %%
df1
# Out:
#   ename  eid  dept_no
# 0     A   12        1
# 1     B   34        2
# 2     C   13        3
# 3     D    5        1
# 4     E   32        1
# 5     A   11        2
# 6     F    3        7

# %%
df2
# Out:
#    dept_no dept_name
# 0        1       dev
# 1        2      test
# 2        3  database
# 3        4       r&d

# %%
pd.merge(df1,df2,on='dept_no',how='inner')
# Out:
#   ename  eid  dept_no dept_name
# 0     A   12        1       dev
# 1     D    5        1       dev
# 2     E   32        1       dev
# 3     B   34        2      test
# 4     A   11        2      test
# 5     C   13        3  database

# %%
pd.merge(df1,df2,on='dept_no',how='left')
# Out:
#   ename  eid  dept_no dept_name
# 0     A   12        1       dev
# 1     B   34        2      test
# 2     C   13        3  database
# 3     D    5        1       dev
# 4     E   32        1       dev
# 5     A   11        2      test
# 6     F    3        7       NaN

# %%
pd.merge(df1,df2,on='dept_no',how='right')
# Out:
#   ename   eid  dept_no dept_name
# 0     A  12.0        1       dev
# 1     D   5.0        1       dev
# 2     E  32.0        1       dev
# 3     B  34.0        2      test
# 4     A  11.0        2      test
# 5     C  13.0        3  database
# 6   NaN   NaN        4       r&d

# %%
pd.merge(df1,df2,on='dept_no',how='outer')
# Out:
#   ename   eid  dept_no dept_name
# 0     A  12.0        1       dev
# 1     D   5.0        1       dev
# 2     E  32.0        1       dev
# 3     B  34.0        2      test
# 4     A  11.0        2      test
# 5     C  13.0        3  database
# 6     F   3.0        7       NaN
# 7   NaN   NaN        4       r&d
