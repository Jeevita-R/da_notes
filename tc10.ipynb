# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevita-R/da_notes/blob/main/tc10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1=np.arange(1,11)
arr2=arr1**2
arr3=arr1**3

# %%
plt.plot(arr1,arr2)
plt.plot(arr1,arr3)

# %%
plt.subplot(4,3,1)
#plt.plot(arr1,arr2)
plt.subplot(4,3,5)
#plt.plot(arr1,arr3)
plt.subplot(4,3,8)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,2)
plt.plot(arr1,arr2)
plt.title('sqr')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(2,2,3)
plt.plot(arr1,arr3,color='red')
plt.title('cube')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(2,2,1)
plt.plot(arr1,arr2)

# %%
plt.subplot(5,2,2)
plt.plot(arr1,arr2)
plt.subplot(5,2,3)
plt.plot(arr1,arr2)
plt.subplot(5,2,6)
plt.plot(arr1,arr2)
plt.subplot(5,2,7)
plt.plot(arr1,arr2)
plt.subplot(5,2,10)
plt.plot(arr1,arr2)

# %%
fig=plt.figure()
axis1=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
f=plt.figure()
a1=f.add_axes([0.1,0.1,0.8,0.8])
a2=f.add_axes([0.5,0.5,0.4,0.4])
a1.plot(arr1,arr2)
a2.plot(arr1,arr3)

# %%
f=plt.figure()
a1=f.add_axes([0.1,0,0.9,1])
a2=f.add_axes([0.2,0.1,0.7,0.8])
a3=f.add_axes([0.55,0.5,0.35,0.4])
a4=f.add_axes([0.2,0.1,0.35,0.4])

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)
axes[0][1].plot(arr1,arr2)

# %%
fig,axes=plt.subplots(nrows=1,ncols=5)
axes[1].plot(arr1,arr2)
